# %% [markdown]
# <a href="https://colab.research.google.com/github/konakanchidhanush/OIBSIB/blob/main/task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numpy is an open library
import numpy as np

# %%
#seaborn is an open library
import seaborn as sns

# %%
#matplot is an open library
import matplotlib.pyplot as plt

# %%
#pandas is an open library
import pandas as pd

# %%
#drf1 is a variable and here csv file is been assigned to it...
drf1= pd.read_csv("/content/IRIS.csv")

# %%
drf1.head(7)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa

# %%
drf1=pd.DataFrame(drf1)
drf1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#shape of drf1
drf1.shape
# Out:
# (150, 5)

# %%
drf1['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
#information of drf1
drf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
drf1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
drf1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
#description of drf1
drf1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#isnull() function and sum() function
drf1.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#correlation of data
drf1.corr()
# Out:
# <ipython-input-15-43319eda8311>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   drf1.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
corr= drf1.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values);
# Out:
# <ipython-input-16-e13319234a22>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= drf1.corr()

# %%
x=drf1.iloc[:,:4]
y=drf1.iloc[:,:4]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
for column in drf1:
  sns.displot(x=column,data=drf1)

# %%
sns.pairplot(drf1)

# %%
color=["blue","green","red"]
species=["Iris-etosa","Iris-versicolor","Iris-virginica"]
for i in range(3):
  x=drf1[drf1['species']==species[i]]
  plt.scatter(x['sepal_length'],x['sepal_width'],c=color[i],label=species[i])
plt.xlabel('sepal_length')
plt.xlabel('sepal_width')
plt.legend()

# %%
drf1["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
sns.violinplot(data=drf1, x='sepal_width')
# Out:
# <Axes: xlabel='sepal_width'>

# %%
sns.distplot(drf1["sepal_width"])
# Out:
# <ipython-input-24-fae5ff1ace90>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(drf1["sepal_width"])
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.violinplot(data=drf1, x='sepal_length', y='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.countplot(data=drf1, x='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.jointplot(data=drf1,x='sepal_width',y='sepal_length')

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=drf1, kind="hex",color="pink")

# %%
sns.scatterplot(data=drf1, x="petal_length", y="petal_width", hue="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.lmplot(x="petal_length", y="petal_width", hue="species", data=drf1)

# %%
drf1["sepal_length"].max()
# Out:
# 7.9

# %%
drf1.groupby("species").std()["petal_length"]
# Out:
# species
# Iris-setosa        0.173511
# Iris-versicolor    0.469911
# Iris-virginica     0.551895
# Name: petal_length, dtype: float64

# %%
#thankyou.............
